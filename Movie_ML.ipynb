# %% [markdown]
# <a href="https://colab.research.google.com/github/jeonjnh/python_ML/blob/main/Movie_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import json

# %% [markdown]
# # Read Data

# %%
meta = pd.read_csv('C:\WorkSpace_ML\movies_metadata.csv')
meta.head()
# Out:
# C:\Users\Jeon\AppData\Local\Temp\ipykernel_6732\3143223244.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   meta = pd.read_csv('C:\WorkSpace_ML\movies_metadata.csv')
#    adult                              belongs_to_collection    budget
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000  \
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...  \
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
# ...

# %%
meta = meta[['id', 'original_title','original_language','genres']]
meta.head()
# Out:
#       id               original_title original_language
# 0    862                    Toy Story                en  \
# 1   8844                      Jumanji                en
# 2  15602             Grumpier Old Men                en
# 3  31357            Waiting to Exhale                en
# 4  11862  Father of the Bride Part II                en
#
#                                               genres
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]

# %%
meta = meta.rename(columns={'id':'movieId'})
meta = meta[meta['original_language'] == 'en']
meta.head()
# Out:
#   movieId               original_title original_language
# 0     862                    Toy Story                en  \
# 1    8844                      Jumanji                en
# 2   15602             Grumpier Old Men                en
# 3   31357            Waiting to Exhale                en
# 4   11862  Father of the Bride Part II                en
#
#                                               genres
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]

# %%
ratings = pd.read_csv('ratings_small.csv')
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1       31     2.5  1260759144
# 1       1     1029     3.0  1260759179
# 2       1     1061     3.0  1260759182
# 3       1     1129     2.0  1260759185
# 4       1     1172     4.0  1260759205

# %%
ratings = ratings[['userId','movieId','rating']]
ratings.head()
# Out:
#    userId  movieId  rating
# 0       1       31     2.5
# 1       1     1029     3.0
# 2       1     1061     3.0
# 3       1     1129     2.0
# 4       1     1172     4.0

# %%
ratings.describe()
# Out:
#               userId        movieId         rating
# count  100004.000000  100004.000000  100004.000000
# mean      347.011310   12548.664363       3.543608
# std       195.163838   26369.198969       1.058064
# min         1.000000       1.000000       0.500000
# 25%       182.000000    1028.000000       3.000000
# 50%       367.000000    2406.500000       4.000000
# 75%       520.000000    5418.000000       4.000000
# max       671.000000  163949.000000       5.000000

# %% [markdown]
# # Refine Dataset

# %%
meta.movieId = pd.to_numeric(meta.movieId, errors='coerce')
meta.head()
# Out:
#    movieId               original_title original_language
# 0      862                    Toy Story                en  \
# 1     8844                      Jumanji                en
# 2    15602             Grumpier Old Men                en
# 3    31357            Waiting to Exhale                en
# 4    11862  Father of the Bride Part II                en
#
#                                               genres
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]

# %%
ratings.movieId = pd.to_numeric(ratings.movieId, errors='coerce')
ratings.head()
# Out:
# C:\Users\Jeon\AppData\Local\Temp\ipykernel_6732\1855621443.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ratings.movieId = pd.to_numeric(ratings.movieId, errors='coerce')
#    userId  movieId  rating
# 0       1       31     2.5
# 1       1     1029     3.0
# 2       1     1061     3.0
# 3       1     1129     2.0
# 4       1     1172     4.0

# %%
def parse_genres(genres_str):
    genres = json.loads(genres_str.replace('\'','"'))
    genres_list = []
    for g in genres:
        genres_list.append(g['name'])
    return genres_list

# %%
# Test
g_str = "[{'id': 16, 'name': 'Animation'}, {'id': 35, 'name': 'Comedy'}, {'id': 10751, 'name': 'Family'}]"
aa = parse_genres(g_str)
aa
# Out:
# ['Animation', 'Comedy', 'Family']

# %%
meta['genres'] = meta['genres'].apply(parse_genres)
meta.head()
# Out:
#    movieId               original_title original_language
# 0      862                    Toy Story                en  \
# 1     8844                      Jumanji                en
# 2    15602             Grumpier Old Men                en
# 3    31357            Waiting to Exhale                en
# 4    11862  Father of the Bride Part II                en
#
#                          genres
# 0   [Animation, Comedy, Family]
# 1  [Adventure, Fantasy, Family]
# 2             [Romance, Comedy]
# 3      [Comedy, Drama, Romance]
# 4                      [Comedy]

# %% [markdown]
# # Merge Meta and Ratings

# %%
data = pd.merge(ratings,meta, on='movieId', how='inner')
data.head()
# Out:
#    userId  movieId  rating original_title original_language   genres
# 0       1     1371     2.5      Rocky III                en  [Drama]
# 1       4     1371     4.0      Rocky III                en  [Drama]
# 2       7     1371     3.0      Rocky III                en  [Drama]
# 3      19     1371     4.0      Rocky III                en  [Drama]
# 4      21     1371     3.0      Rocky III                en  [Drama]

# %% [markdown]
# # Pivot Table

# %%
matrix = data.pivot_table(index='userId',columns='original_title',values='rating')
matrix.head(20)
# Out:
# original_title  !Women Art Revolution  'Gator Bait
# userId
# 1                                 NaN          NaN  \
# 2                                 NaN          NaN
# 3                                 NaN          NaN
# 4                                 NaN          NaN
# 5                                 NaN          NaN
# 6                                 NaN          NaN
# 7                                 NaN          NaN
# 8                                 NaN          NaN
# 9                                 NaN          NaN
# 10                                NaN          NaN
# 11                                NaN          NaN
# 12                                NaN          NaN
# 13                                NaN          NaN
# 14                                NaN          NaN
# 15                                NaN          0.5
# 16                                NaN          NaN
# 17                                NaN          NaN
# ...

# %% [markdown]
# # Pearson Correlation
# https://namu.wiki/w/%EC%83%81%EA%B4%80%20%EA%B3%84%EC%88%98?from=%ED%94%BC%EC%96%B4%EC%8A%A8%20%EC%83%81%EA%B4%80%20%EA%B3%84%EC%88%98#s-2

# %%
GENRE_WEIGHT = 0.1

def pearson(s1, s2):
    s1_c = s1 - s1.mean()
    s2_c = s2 - s2.mean()
    return np.sum(s1_c * s2_c) / np.sqrt(np.sum(s1_c**2) * np.sum(s2_c**2))

def recommend(input_movie, matrix, n, similar_genre=True):
    input_genres = meta[meta['original_title'] == input_movie]['genres'].iloc(0)[0]

    result = []

    for title in matrix.columns:
        if title == input_movie:
            continue

        #rating comparison
        cor = pearson(matrix[input_movie], matrix[title])

        #gerne comparison
        if similar_genre and len(input_genres) > 0:
            temp_genres = meta[meta['original_title'] == input_movie]['genres'].iloc(0)[0]
            same_count = np.sum(np.isin(input_genres, temp_genres))
            cor += (GENRE_WEIGHT * same_count)

        if np.isnan(cor):
            continue
        else:
            result.append((title, '{:.2f}'.format(cor),temp_genres))

    result.sort(key=lambda r:r[1], reverse=True)
    return result[:n]

# %% [markdown]
# # Prediction

# %%
recommend_result = recommend('The Dark Knight', matrix, 10, similar_genre=True)
recommend_result
# Out:
# C:\Users\Jeon\AppData\Local\Temp\ipykernel_6732\1708618618.py:6: RuntimeWarning: invalid value encountered in scalar divide
#   return np.sum(s1_c * s2_c) / np.sqrt(np.sum(s1_c**2) * np.sum(s2_c**2))
# [('Prom Night', '1.17', ['Drama', 'Action', 'Crime', 'Thriller']),
#  ('Wild Wild West', '1.17', ['Drama', 'Action', 'Crime', 'Thriller']),
#  ('Ludwig', '0.87', ['Drama', 'Action', 'Crime', 'Thriller']),
#  ('El asaltante', '0.85', ['Drama', 'Action', 'Crime', 'Thriller']),
#  ('Sneakers', '0.82', ['Drama', 'Action', 'Crime', 'Thriller']),
#  ('Godzilla', '0.81', ['Drama', 'Action', 'Crime', 'Thriller']),
#  ('Bushwhacked', '0.80', ['Drama', 'Action', 'Crime', 'Thriller']),
#  ('Pirates of the Caribbean: On Stranger Tides',
#   '0.80',
#   ['Drama', 'Action', 'Crime', 'Thriller']),
#  ('Wet Hot American Summer', '0.79', ['Drama', 'Action', 'Crime', 'Thriller']),
#  ('Deadlier Than the Male', '0.78', ['Drama', 'Action', 'Crime', 'Thriller'])]

# %%
pd.DataFrame(recommend_result, columns = ['Title', 'Correlation', 'Genre'])
# Out:
#                                          Title Correlation
# 0                                   Prom Night        1.17  \
# 1                               Wild Wild West        1.17
# 2                                       Ludwig        0.87
# 3                                 El asaltante        0.85
# 4                                     Sneakers        0.82
# 5                                     Godzilla        0.81
# 6                                  Bushwhacked        0.80
# 7  Pirates of the Caribbean: On Stranger Tides        0.80
# 8                      Wet Hot American Summer        0.79
# 9                       Deadlier Than the Male        0.78
#
#                               Genre
# 0  [Drama, Action, Crime, Thriller]
# 1  [Drama, Action, Crime, Thriller]
# 2  [Drama, Action, Crime, Thriller]
# 3  [Drama, Action, Crime, Thriller]
# 4  [Drama, Action, Crime, Thriller]
# 5  [Drama, Action, Crime, Thriller]
# 6  [Drama, Action, Crime, Thriller]
# ...
